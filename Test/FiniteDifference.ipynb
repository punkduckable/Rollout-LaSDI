# %%
import  os;
import  sys;
util_Path : str = os.path.join(os.path.join(os.path.pardir, "src"), "Utilities");
sys.path.append(util_Path);

import  colorsys;

import  torch;
import  matplotlib          as  mpl;
import  matplotlib.pyplot   as  plt;
import  seaborn;

import  FiniteDifference;

def Initialize_MPL() -> None:
    """
    This function initialize matplotlib's parameter so that the plots it generates are less ugly.
    This function has no arguments or return variables.
    """

    # Now... let's set up plot formatting.
    def scale_lightness(rgb, scale_l):
        # convert rgb to hls
        h, l, s = colorsys.rgb_to_hls(*rgb)

        # manipulate h, l, s values and return as rgb
        return colorsys.hls_to_rgb(h, min(1, l * scale_l), s = s)

    seaborn.set_context(context     = "paper");
    seaborn.set_style(  style       = "darkgrid");
    mpl.rcParams["lines.linewidth"] = 2;
    mpl.rcParams["axes.linewidth"]  = 1.5;
    mpl.rcParams["axes.edgecolor"]  = "black";
    mpl.rcParams["grid.color"]      = "gray";
    mpl.rcParams["grid.linestyle"]  = "dotted";
    mpl.rcParams["grid.linewidth"]  = .67;
    mpl.rcParams["xtick.labelsize"] = 10;
    mpl.rcParams["ytick.labelsize"] = 10;
    mpl.rcParams["axes.labelsize"]  = 11;
    mpl.rcParams["axes.titlesize"]  = 12;
    mpl.rcParams["axes.facecolor"]  = scale_lightness(mpl.colors.ColorConverter.to_rgb("lightgrey"), 1.15);

Initialize_MPL();

# %% [markdown]
# ### Scalar valued test
#
# Set up a function and it's derivative for testing.

# %%
def F(t : torch.Tensor) -> torch.Tensor:
    # Computes exp(sin(t^2))
    assert(len(t.shape) == 1);

    t2 : torch.Tensor = torch.multiply(t, t);
    return torch.exp(torch.sin(t2))



def dF_dt(t : torch.Tensor) -> torch.Tensor:
    # Computes (d/dt)exp(sin(t)) = exp(sin(t^2))cos(t^2)2t
    assert(len(t.shape) == 1);

    t2 : torch.Tensor = torch.multiply(t, t);
    return torch.multiply(torch.multiply(torch.exp(torch.sin(t2)), torch.cos(t2)), 2*t);



def d2F_dt2(t : torch.Tensor) -> torch.Tensor:
    # Computes (d^2/dt^2)exp(sin(t^2)) = exp(sin(t^2))cos(t^2)^2 (4t^2) - exp(sin(t^2))sin(t^2)(4t^2) + 2exp(sin(t^2))cos(t^2)
    assert(len(t.shape) == 1);

    t2          : torch.Tensor  = torch.multiply(t, t);
    sin_t2      : torch.Tensor  = torch.sin(t2);
    cos_t2      : torch.Tensor  = torch.cos(t2);
    exp_sin_t2  : torch.Tensor  = torch.exp(sin_t2);

    return torch.multiply(torch.multiply(exp_sin_t2, torch.multiply(cos_t2, cos_t2)), 4*t2) - torch.multiply(torch.multiply(exp_sin_t2, sin_t2), 4*t2) + 2*torch.multiply(exp_sin_t2, cos_t2);

# %%
h                   : float         = 0.02;
t                   : torch.Tensor  = torch.arange(start = 0, end = 15, step = h);

Ft                  : torch.Tensor  = F(t).reshape(-1, 1);

dF_dt_True          : torch.Tensor  = dF_dt(t).reshape(-1, 1);
dF_dt_2_Predict     : torch.Tensor  = FiniteDifference.Derivative1_Order2(U = Ft, h = h);
dF_dt_4_Predict     : torch.Tensor  = FiniteDifference.Derivative1_Order4(U = Ft, h = h);

d2F_dt2_True        : torch.Tensor  = d2F_dt2(t).reshape(-1, 1);
d2F_dt2_2_Predict   : torch.Tensor  = FiniteDifference.Derivative2_Order2(U = Ft, h = h);
d2F_dt2_4_Predict   : torch.Tensor  = FiniteDifference.Derivative2_Order4(U = Ft, h = h);

# %%
# First Derivative
plt.figure();
plt.plot(t,     dF_dt_True,         label = "True");
plt.plot(t,     dF_dt_2_Predict,    label = r"$\mathcal{O}(h^2)$ prediction");
plt.plot(t,     dF_dt_4_Predict,    label = r"$\mathcal{O}(h^4)$ prediction");

plt.title("First Derivative");
plt.legend();



# First Derivative Error
plt.figure();
plt.plot(t,     dF_dt_True - dF_dt_2_Predict,   label = r"$\mathcal{O}(h^2)$ error");
plt.plot(t,     dF_dt_True - dF_dt_4_Predict,   label = r"$\mathcal{O}(h^4)$ error");

plt.title("First Derivative Error");
plt.legend();



# Second Derivative
plt.figure();
plt.plot(t[-5:],     d2F_dt2_True[-5:],       label = "True");
plt.plot(t[-5:],     d2F_dt2_2_Predict[-5:],  label = r"$\mathcal{O}(h^2)$ prediction");
plt.plot(t[-5:],     d2F_dt2_4_Predict[-5:],  label = r"$\mathcal{O}(h^4)$ prediction");

plt.title("Second Derivative");
plt.legend();



# Second Derivative Error
plt.figure();
plt.plot(t[-5:],     (d2F_dt2_True - d2F_dt2_2_Predict)[-5:],  label = r"$\mathcal{O}(h^2)$ error");
plt.plot(t[-5:],     (d2F_dt2_True - d2F_dt2_4_Predict)[-5:],  label = r"$\mathcal{O}(h^4)$ error");

plt.title("Second Derivative Error");
plt.legend();

plt.show()

# %% [markdown]
# # First Derivative Non-Uniform Test

# %%
# Set up a non-uniform grid.
import random;
h                   : float         = 0.02;
dh                  : float         = 0.01;
n_steps             : int           = round(20./h);
t        : torch.Tensor  = torch.empty(n_steps, dtype = torch.float32);
t[0] = 5;
for i in range(1, n_steps):
    hi              = h + dh*(random.random() - .5);
    t[i] = t[i - 1] + hi;

# Compute derivatives + their approximations.
Ft              : torch.Tensor  = F(t).reshape(-1, 1);

dF_dt_True      : torch.Tensor  = dF_dt(t).reshape(-1, 1);
dF_dt_2_Predict : torch.Tensor  = FiniteDifference.Derivative1_Order2_NonUniform(U = Ft, t_Grid = t);


# Now set up a uniform grid. In this case, the uniform and non-uniform methods should give the same result.
t_uniform                   : torch.Tensor  = torch.arange(start = 5, end = 25, step = h);
Ft_uniform                  : torch.Tensor  = F(t_uniform).reshape(-1, 1);
dF_dt_True_uniform          : torch.Tensor  = dF_dt(t = t_uniform);
dF_dt_2_Predict_uniform     : torch.Tensor  = FiniteDifference.Derivative1_Order2(U = Ft_uniform, h = h);
dF_dt_2_Predict_nonuniform  : torch.Tensor  = FiniteDifference.Derivative1_Order2_NonUniform(U = Ft_uniform, t_Grid = t_uniform);

# %%
# First Derivative - Nonuniform
plt.figure();
plt.plot(t,     dF_dt_True,         label = "True");
plt.plot(t,     dF_dt_2_Predict,    label = r"$\mathcal{O}(h^2)$ prediction");

plt.title("First Derivative - Nonuniform t spacing");
plt.legend();


# First Derivative Error - Nonuniform
plt.figure();
plt.plot(t,     dF_dt_True - dF_dt_2_Predict,   label = r"$\mathcal{O}(h^2)$ error");

plt.title("First Derivative Error - Nonuniform t spacing");
plt.legend();


# First derivative - Uniform
plt.figure();
plt.plot(t,     dF_dt_True_uniform,         label = "True");
plt.plot(t,     dF_dt_2_Predict_nonuniform, label = "Prediction using non-uniform method");
plt.plot(t,     dF_dt_2_Predict_uniform,    label = "Prediction using uniform method");

plt.title("First Derivative - Uniform t spacing");
plt.legend();


# First derivative Error - Uniform
plt.figure();
plt.plot(t,     dF_dt_2_Predict_nonuniform - dF_dt_2_Predict_uniform,         label = "Uniform minus non-uniform prediction");

plt.title("Difference between the two prediction - Uniform t spacing");
plt.legend();

# %% [markdown]
# # Second-Derivative Non-Uniform Test

# %%
# Set up a non-uniform grid.
import random;
h                   : float         = 0.02;
dh                  : float         = 0.01;
n_steps             : int           = round(20./h);
t        : torch.Tensor  = torch.empty(n_steps, dtype = torch.float32);
t[0] = 5.0;
for i in range(1, n_steps):
    hi              = h + dh*(random.random() - .5);
    t[i] = t[i - 1] + hi;


# Compute derivatives + their approximations.
Ft                              : torch.Tensor  = F(t).reshape(-1, 1);

d2F_dt2_True                    : torch.Tensor  = d2F_dt2(t).reshape(-1, 1);
d2F_dt2_2_Predict               : torch.Tensor  = FiniteDifference.Derivative2_Order2_NonUniform(U = Ft, t_Grid = t);


# Now set up a uniform grid. In this case, the uniform and non-uniform methods should give the same result.
t_uniform                       : torch.Tensor  = torch.arange(start = 5, end = 25, step = h);

Ft_uniform                      : torch.Tensor  = F(t_uniform).reshape(-1, 1);

d2F_dt2_True_uniform            : torch.Tensor  = d2F_dt2(t = t_uniform);
d2F_dt2_2_Predict_uniform       : torch.Tensor  = FiniteDifference.Derivative2_Order2(U = Ft_uniform, h = h);
d2F_dt2_2_Predict_nonuniform    : torch.Tensor  = FiniteDifference.Derivative2_Order2_NonUniform(U = Ft_uniform, t_Grid = t_uniform);

# %%
# Second Derivative - Nonuniform
plt.figure();
plt.plot(t[:5],     d2F_dt2_True[:5],         label = "True");
plt.plot(t[:5],     d2F_dt2_2_Predict[:5],    label = r"$\mathcal{O}(h^2)$ prediction");

plt.title("Second Derivative - Nonuniform t spacing");
plt.legend();


# Second Derivative Error - Nonuniform
plt.figure();
plt.plot(t,     d2F_dt2_True - d2F_dt2_2_Predict,   label = r"$\mathcal{O}(h^2)$ error");

plt.title("Second Derivative Error - Nonuniform t spacing");
plt.legend();


# Second derivative - Uniform
plt.figure();
plt.plot(t,     d2F_dt2_True_uniform,         label = "True");
plt.plot(t,     d2F_dt2_2_Predict_nonuniform, label = "Prediction using non-uniform method");
plt.plot(t,     d2F_dt2_2_Predict_uniform,    label = "Prediction using uniform method");

plt.title("Second Derivative - Uniform t spacing");
plt.legend();


# Second derivative Error - Uniform
plt.figure();
plt.plot(t,     (d2F_dt2_2_Predict_nonuniform - d2F_dt2_2_Predict_uniform),         label = "Uniform minus non-uniform prediction");

plt.title("Difference between the two prediction - Uniform t spacing");
plt.legend();

# %% [markdown]
# ### Convergence test

# %%
# Set up a few non-uniform grids.
import random;
h8          : float         = 0.08;
h4          : float         = 0.04;
h2          : float         = 0.02;

dh8         : float         = h8/3;
dh4         : float         = h4/3;
dh2         : float         = h2/3;

n_steps8    : int           = round(20./h8); 
n_steps4    : int           = round(20./h4); 
n_steps2    : int           = round(20./h2); 

t8          : torch.Tensor  = torch.empty(n_steps8, dtype = torch.float32);
t4          : torch.Tensor  = torch.empty(n_steps4, dtype = torch.float32);
t2          : torch.Tensor  = torch.empty(n_steps2, dtype = torch.float32);

t8[0] = 5.0;
for i in range(1, n_steps8):
    h8i              = h8 + dh8*(random.random() - .5);
    t8[i] = t8[i - 1] + h8i;

t4[0] = 5.0;
for i in range(1, n_steps4):
    h4i              = h4 + dh4*(random.random() - .5);
    t4[i] = t4[i - 1] + h4i;

t2[0] = 5.0;
for i in range(1, n_steps2):
    h2i              = h2 + dh2*(random.random() - .5);
    t2[i] = t2[i - 1] + h2i;

# Compute derivatives + their approximations.
Ft8                 : torch.Tensor  = F(t8).reshape(-1, 1);
Ft4                 : torch.Tensor  = F(t4).reshape(-1, 1);
Ft2                 : torch.Tensor  = F(t2).reshape(-1, 1);

dF_dt_True8         : torch.Tensor  = dF_dt(t8).reshape(-1, 1);
dF_dt_True4         : torch.Tensor  = dF_dt(t4).reshape(-1, 1);
dF_dt_True2         : torch.Tensor  = dF_dt(t2).reshape(-1, 1);

dF_dt_Predict8      : torch.Tensor  = FiniteDifference.Derivative1_Order2_NonUniform(U = Ft8, t_Grid = t8);
dF_dt_Predict4      : torch.Tensor  = FiniteDifference.Derivative1_Order2_NonUniform(U = Ft4, t_Grid = t4);
dF_dt_Predict2      : torch.Tensor  = FiniteDifference.Derivative1_Order2_NonUniform(U = Ft2, t_Grid = t2);

d2F_dt2_True8       : torch.Tensor  = d2F_dt2(t8).reshape(-1, 1);
d2F_dt2_True4       : torch.Tensor  = d2F_dt2(t4).reshape(-1, 1);
d2F_dt2_True2       : torch.Tensor  = d2F_dt2(t2).reshape(-1, 1);

d2F_dt2_Predict8    : torch.Tensor  = FiniteDifference.Derivative2_Order2_NonUniform(U = Ft8, t_Grid = t8);
d2F_dt2_Predict4    : torch.Tensor  = FiniteDifference.Derivative2_Order2_NonUniform(U = Ft4, t_Grid = t4);
d2F_dt2_Predict2    : torch.Tensor  = FiniteDifference.Derivative2_Order2_NonUniform(U = Ft2, t_Grid = t2);

# %%
# First Derivative.
plt.figure();
plt.plot(t8,     dF_dt_Predict8 - dF_dt_True8,        label = "Error - mean h = 0.08");
plt.plot(t4,     dF_dt_Predict4 - dF_dt_True4,        label = "Error - mean h = 0.04");
plt.plot(t2,     dF_dt_Predict2 - dF_dt_True2,        label = "Error - mean h = 0.02");

plt.title("First Derivative");
plt.legend();


# Second Derivative.
plt.figure();
plt.plot(t8,     d2F_dt2_Predict8 - d2F_dt2_True8,      label = "Error - mean h = 0.08");
plt.plot(t4,     d2F_dt2_Predict4 - d2F_dt2_True4,      label = "Error - mean h = 0.04");
plt.plot(t2,     d2F_dt2_Predict2 - d2F_dt2_True2,      label = "Error - mean h = 0.02");

plt.title("Second Derivative");
plt.legend();
